# %% [markdown]
# <!-- Wyodrębnij informacje ze ścieżki do pliku.
# Dane:
# Ścieżka: "data/processed/train_fold_03_normalized.csv"
# Wymagania:
# Wyodrębnij: folder, typ zbioru (train/test), numer fold, format pliku
# Użyj metod split() i indeksowania
# Wyświetl każdą informację osobno -->

# %%
sciezka_do_pliku = "data/processed/train_fold_03_normalized.csv"
czesci_sciezki = sciezka_do_pliku.split("/")
print(czesci_sciezki)
folder = czesci_sciezki[0]
podfolder = czesci_sciezki[1]
nazwa_pliku = czesci_sciezki[-1]
nazwa, format_pliku = nazwa_pliku.split(".")
czesci_nazwy = nazwa.split("_")

print(f"Nazwa folderu: {folder}")
print(f"Nazwa podfolderu: {podfolder}")
print(f"Nazwa pliku: {nazwa_pliku}")
print(f"Nazwa {nazwa}, Format pliku: {format_pliku}")
print(f"Typ zbioru: {czesci_nazwy[0]}")
print(f"Fold: {czesci_nazwy[2][-1:]}")
# Out:
# ['data', 'processed', 'train_fold_03_normalized.csv']
# Nazwa folderu: data
# Nazwa podfolderu: processed
# Nazwa pliku: train_fold_03_normalized.csv
# Nazwa train_fold_03_normalized, Format pliku: csv
# Typ zbioru: train
# Fold: 3

# %% [markdown]
# <!-- Zwaliduj hiperparametry przed treningiem.
# Dane:
# learning_rate = 0.01
# batch_size = 64
# epochs = 100
# dropout = 0.5
# Wymagania:
# Sprawdź czy learning_rate w zakresie (0, 1]
# Sprawdź czy batch_size jest potęgą 2 (użyj operacji bitowych lub logarytmów)
# Sprawdź czy epochs > 0 i < 1000
# Sprawdź czy dropout w zakresie [0, 1]
# Wyświetl "OK" lub komunikat błędu dla każdego parametru -->

# %%
import math

learning_rate = 0.01
batch_size = 64
epochs = 100
dropout = 0.5

def is_a_power_of_two_using_bitwise_operation(number: int):
    return (number > 0 ) and ((number & (number-1)) == 0)


def is_a_power_of_two_using_an_iterative_approach(number: int):
    if number <= 0:
        return False
    
    while (number % 2 == 0):
        number //= 2

    return number == 1


def is_a_power_of_two_using_natural_logarithm(number: int):
    if number <= 0:
        return False
    
    logarithm_value = int(math.log2(number))

    print(f"{logarithm_value} , { 2 ** logarithm_value}")

    return (2 ** logarithm_value) == number


print(f"Czy learning rate jest w zakresie (0, 1]?: {("Błąd! Parametr learning rate jest poza zakresem.", "OK")[(learning_rate > 0 and learning_rate <= 1)]}")

# if is_a_power_of_two_using_an_iterative_approach(batch_size):
# if is_a_power_of_two_using_natural_logarithm(batch_size):
if is_a_power_of_two_using_bitwise_operation(batch_size):
    message = "OK"
else:
    message = "Błąd! Parametr batch_size nie jest potęgą 2."

print(f"Czy batch_size jest potęgą 2?: {message}")


if epochs > 0 and epochs < 1000:
    message = "OK"
else:
    message = "Błąd! Epoka poza zakresem."

print(f"Czy epochs > 0 i < 1000?: {message}")


if dropout >= 0 and dropout <= 1:
    message = "OK"
else:
    message = "Błąd! Dropout poza zakresem."

print(f"Czy dropout w zakresie [0, 1]?: {message}")

# print(f"Czy epochs > 0 i < 1000?: {"OK" if epochs > 0 and epochs < 1000 else "Błąd! Epoka poza zakresem."}")
# print(f"Czy dropout w zakresie [0, 1]?: {({True: "OK", False:"Błąd! Dropout poza zakresem."}[dropout >= 0 and dropout <= 1])}")
# print(f"Czy dropout w zakresie [0, 1]?: {(lambda parameter: "OK" if parameter >= 0 and parameter <= 1 else "Błąd! Dropout poza zakresem.")(dropout)}")
# Out:
# Czy learning rate jest w zakresie (0, 1]?: OK
# Czy batch_size jest potęgą 2?: OK
# Czy epochs > 0 i < 1000?: OK
# Czy dropout w zakresie [0, 1]?: OK

# %% [markdown]
# <!-- Stwórz sformatowany raport wyników.
# Dane:
# Nazwa modelu: "XGBoost Classifier"
# Dataset: "Credit Card Fraud"
# Liczba próbek: 284807
# Accuracy: 0.9991
# Precision: 0.8876
# Recall: 0.7561
# F1-Score: oblicz ze wzoru 2×(precision×recall)/(precision+recall)
# Wymagania:
# Użyj f-strings do budowy raportu
# Zastosuj wyrównanie kolumn
# Liczba próbek z separatorem tysięcy
# Metryki w procentach z odpowiednią precyzją
# Raport w ramce z linii = -->

# %%
import math

print(math.isclose(0.51, 0))

model_name = "XGBoost Classifier"
dataset_name = "Credit Card Fraud"
number_of_samples = 284807
accuracy = 0.9991
precision = 0.8876
recall = 0.7561

print(f"""
{'='*60}
RAPORT MODELU
{'='*60}
Model:           {model_name}
Liczba próbek:   {number_of_samples:,}
Accuracy:        {accuracy:.2%}
Precision:       {precision:.2%}
Recall:          {recall:.2%}
F1-Score         {2 * (precision * recall) / (precision + recall):.2%}
""")
# Out:
# False
#
# ============================================================
# RAPORT MODELU
# ============================================================
# Model:           XGBoost Classifier
# Liczba próbek:   284,807
# Accuracy:        99.91%
# Precision:       88.76%
# Recall:          75.61%
# F1-Score         81.66%

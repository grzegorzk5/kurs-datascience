# %% [markdown]
# <!-- Sformatuj metryki modelu.
# Dane:
# Accuracy: 0.9234
# Precision: 0.8891
# Recall: 0.9456
# Wymagania:
# Wyświetl każdą metrykę w procentach z 2 miejscami po przecinku
# Użyj f-strings z formatowaniem :.2%
# Dodaj estetyczne wyrównanie kolumn -->

# %%
accuracy = 0.9234
precision = 0.8891
recall = 0.9456

headers = ["Accuracy", "Precision", "Recall"]

# print(f"{headers[0]:<15} {headers[1]:<15} {headers[2]:<15}")
# print(f"{accuracy:<15.2%} {precision:<15.2%} {recall:<15.2%}")

metryki_modelu = [
    {
        "nazwa": "Accuracy",
        "wartosc": 0.9234
    },
    {
        "nazwa": "Precision",
        "wartosc": 0.8891     
    },
    {
        "nazwa": "Recall",
        "wartosc": 0.9456      
    }
]
# print("-"*50)
print(f"{metryki_modelu[0]["nazwa"]:<15} {metryki_modelu[1]["nazwa"]:<15} {metryki_modelu[2]["nazwa"]:<15}")
print(f"{metryki_modelu[0]["wartosc"]:<15.2%} {metryki_modelu[1]["wartosc"]:<15.2%} {metryki_modelu[2]["wartosc"]:<15.2%}")
# Out:
# Accuracy        Precision       Recall
# 92.34%          88.91%          94.56%

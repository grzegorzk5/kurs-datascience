# %% [markdown]
# Zadanie 2
#
# Masz listę temperatury: [-5, 3, -2, 8, 12, -1, 6, 0, 15, -3] . Oblicz sumę tylko dodatnich wartości używając pętli for i instrukcji warunkowej.
#
# Wymagania:
# - Użyj zmiennej suma = 0
# - W pętli sprawdzaj if temp > 0:
# - Dodaj tylko dodatnie wartości do sumy
#
# Oczekiwany rezultat:
# - Wyświetlenie sumy dodatnich temperatur
# - Liczba dodatnich pomiarów

# %%
temperatury = [-5, 3, -2, 8, 12, -1, 6, 0, 15, -3]

suma = 0
liczba_dodatnich_pomiarow = 0

for temp in temperatury:
    if temp > 0:
        suma += temp
        liczba_dodatnich_pomiarow += 1

print(f'Suma dodatnich temperatur: {suma}')
print(f'Liczba dodatnich pomiarów: {liczba_dodatnich_pomiarow}')
# Out:
# Suma dodatnich temperatur: 44
# Liczba dodatnich pomiarów: 5

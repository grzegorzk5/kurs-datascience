# %% [markdown]
# Zadanie 3
#
# Masz listę słów: ['python', 'java', 'python', 'javascript', 'python', 'java',
# 'c++', 'python'] . Policz ile razy każde słowo występuje używając słownika.
#
# Wymagania:
# - Użyj pętli i metody .get()
# - Wypisz wyniki
#
# Oczekiwany wynik:
# - Słownik z częstościami: {'python': 4, 'java': 2, ...}

# %%
words = ['python', 'java', 'python', 'javascript', 'python', 'java', 'c++', 'python']

word_frequency = dict()

for word in words:
    word_frequency[word] = word_frequency.get(word, 0) + 1

print(f"Częstości słów: {word_frequency}")
# Out:
# Częstości słów: {'python': 4, 'java': 2, 'javascript': 1, 'c++': 1}

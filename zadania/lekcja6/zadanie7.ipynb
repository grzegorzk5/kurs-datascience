# %% [markdown]
# Zadanie 7
#
# Napisz funkcję analiza_liczb(lista) która zwraca krotkę z: sumą, średnią, minimum i
# maksimum z listy. Przetestuj na liście [10, 20, 30, 40, 50] .
#
# Wymagania:
# - Funkcja zwraca krotkę z 4 wartościami
# - Użyj tuple unpacking przy wywołaniu
# - Wypisz wyniki

# %%
def analiza_liczb(lista):
    suma = sum(lista)
    srednia = suma / len(lista)
    minimum = min(lista)
    maksimum = max(lista)
    return suma, srednia, minimum, maksimum

dane = [10, 20, 30, 40, 50]
total_val, avg, min_val, max_val = analiza_liczb(dane)
print(f"Suma: {total_val}, Średnia: {avg}, Minimum: {min_val}, Maksimum: {max_val}")
# Out:
# Suma: 150, Średnia: 30.0, Minimum: 10, Maksimum: 50

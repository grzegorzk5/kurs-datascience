# %% [markdown]
# Zadanie 8
#
# Masz nazwę pliku: "model_results_2024_Q3.csv" . Wyciągnij rok i kwartał używając
# slicing lub split.

# %%
print("Test")
filename = "model_results_2024_Q3.csv"
# year = filename[14:18]
# quarter = filename[19:21]
year = filename[-11:-7]
quarter = filename[-6:-4]

year, quarter = filename.split('.')[-2].split('_')[-2:4]
output = filename.split('.')[-2].split('_')[-2:4]

print(output)

print(f"Rok: {year} , Kwartał: {quarter}")
# Out:
# Test
# ['2024', 'Q3']
# Rok: 2024 , Kwartał: Q3

# %% [markdown]
# Zadanie 4
#
# Masz listę nazw kolumn: [" Customer ID ", "TOTAL AMOUNT", " date "] . Wyczyść je
# zgodnie z konwencją:
# Usuń białe znaki (strip)
# Zamień na małe litery (lower)
# Zamień spacje na podkreślniki (replace)

# %%
column_names = [" Customer ID ", "TOTAL AMOUNT", " date "]

print(f"Oryginalne nazwy kolumn: {column_names}")

# sposób 1
# cleaned_column_names = []
# for column_name in column_names:
#     column_name = column_name.strip()
#     column_name = column_name.lower()
#     column_name = column_name.replace(" ", "_")    
#     cleaned_column_names.append(column_name)

# sposób 1 - krótsza wersja
# for column_name in column_names:
#     cleaned_column_names.append(column_name.strip().lower().replace(" ", "_"))

# spsób 2
cleaned_column_names = [column_name.strip().lower().replace(" ", "_") for column_name in column_names]
print(f"Wyczyszczone nazwy kolumn: {cleaned_column_names}")
# Out:
# Oryginalne nazwy kolumn: [' Customer ID ', 'TOTAL AMOUNT', ' date ']
# Wyczyszczone nazwy kolumn: ['customer_id', 'total_amount', 'date']

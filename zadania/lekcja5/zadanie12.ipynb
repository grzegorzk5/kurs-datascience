# %% [markdown]
# Zadanie 12
#
# Masz:
# - Tabelę: "customers"
# - Kolumny do wybrania: ['id', 'name', 'email', 'city']
# - Warunek: "city = 'New York'"
#
# Zbuduj string z query SQL używając join() :
# SELECT id, name, email, city FROM customers WHERE city = 'New York'

# %%
table_name = "customers"
column_names = ['id', 'name', 'email', 'city']
condition = "city = 'New York'"

sql_select = f"SELECT {', '.join(column_names)} FROM {table_name} WHERE {condition}"
print(f"SQL: {sql_select}")
# Out:
# SQL: SELECT id, name, email, city FROM customers WHERE city = 'New York'

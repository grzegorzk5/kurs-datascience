# %% [markdown]
# Zadanie 10
#
# Masz listę transakcji (kategoria, kwota):
# transactions = [
# ('food', 50),
# ('transport', 20),
# ('food', 30),
# ('entertainment', 40),
# ('transport', 15),
# ('food', 25)
# ]
# Oblicz łączną kwotę dla każdej kategorii. Wynik zapisz w słowniku (użyj pętli i warunków).

# %%
transactions = [
    ('food', 50),
    ('transport', 20),
    ('food', 30),
    ('entertainment', 40),
    ('transport', 15),
    ('food', 25)
]

# Sposób 1
# items_cost = {}

# for item in transactions:
#     if item[0] not in items_cost:
#         items_cost[item[0]]=0

#     items_cost[item[0]]+=item[1]

# print(f"Wynik: {items_cost}")

# del items_cost

# Sposób 2
items_cost = {}

for category, amount in transactions:
    if category not in items_cost:
        items_cost[category]=0
    
    items_cost[category] += amount

print(f"Wynik: {items_cost}")
# Out:
# Wynik: {'food': 105, 'transport': 35, 'entertainment': 40}

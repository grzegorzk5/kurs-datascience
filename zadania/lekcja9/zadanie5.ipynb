# %% [markdown]
# Zadanie 5
#
# Stwórz klasę Student z atrybutami: imie , numer_indeksu , oceny (lista ocen).
#
# Metody:
# - dodaj_ocene(ocena) – dodaje ocenę do listy
# - srednia() – zwraca średnią ocen
# - __str__() – reprezentacja tekstowa
#
# Stwórz 3 studentów, dodaj im oceny i wyświetl średnie.

# %%
from typing import Union, List

class Student:
    def __init__(self, imie: str, numer_indeksu:int, oceny:list[int | float]):
        self.imie = imie
        self.numer_indeksu = numer_indeksu
        self.oceny = oceny
    
    def dodaj_ocene(self, ocena:int | float):
        self.oceny.append(ocena)

    def srednia(self) -> list[int | float]:
        return sum(self.oceny) / len(self.oceny)
    
    def __str__(self) -> str:
        return f"{self.imie}, Nr indeksu: {self.numer_indeksu}, Średnia: {self.srednia()}"
    
student1 = Student("Tomasz",4159541, [5, 4.5, 4, 5])
student2 = Student("Magdalena", 4159591, [4, 5.0, 4.5, 5])
student3 = Student("Adam", 4159715, [4, 4.5, 3.5, 4.0])

student1.dodaj_ocene(4.5)
student2.dodaj_ocene(5)
student3.dodaj_ocene(4.5)

print("Lista studentów wraz z ich średnimi:")
print("  ", student1)
print("  ", student2)
print("  ", student3)
# Out:
# Lista studentów wraz z ich średnimi:
#    Tomasz, Nr indeksu: 4159541, Średnia: 4.6
#    Magdalena, Nr indeksu: 4159591, Średnia: 4.7
#    Adam, Nr indeksu: 4159715, Średnia: 4.1
